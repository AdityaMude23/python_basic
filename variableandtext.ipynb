# %%
a = 2
b = '2'

print("a =",a,"type =",type(a))
print("b =",b,"type =",type(b))
# Out:
# a = 2 type = <class 'int'>
# b = 2 type = <class 'str'>

# %%
#print("a + b =", a+b)
print("a + b =", str(a)+b)
print("a + b =", a+int(b))
# Out:
# a + b = 22
# a + b = 4
